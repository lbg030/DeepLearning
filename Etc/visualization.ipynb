# %% [markdown]
# # Random Sampling

# %%
import torch
from torch import nn
import torch.nn.functional as F
 
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.lin1 = nn.Linear(5,5)
 
    def forward(self,x):
        net = self.lin1(x)
        return net
 
device = torch.device("mps") if torch.backends.mps.is_available() else "cpu"
print(f"device: {device}")
 
# MPS 장치에 바로 tensor를 생성합니다.
x = torch.ones(5, device=device)
 
# GPU 상에서 연산 진행
y = x * 2
 
# 또는, 다른 장치와 마찬가지로 MPS로 이동할 수도 있습니다.
model = Net()# 어떤 모델의 객체를 생성한 뒤,
model.to(device) # MPS 장치로 이동합니다.
 
# 이제 모델과 텐서를 호출하면 GPU에서 연산이 이뤄집니다.
pred = model(x)
print(pred)

# %%
f1 = [0.46485, 0.5287, 0.56817, 0.58789, 0.60032, 0.60855, 0.62011, 0.63782, 0.63304, 0.63919]
acc = [0.48127, 0.55783, 0.5957, 0.62498, 0.64555, 0.64909, 0.6668, 0.68233, 0.68015, 0.68587]

# %% [markdown]
# # 1 Layer

# %%
mean_f1 = []
mean_acc = []

acc1 = [0.5292194523906825, 0.5921536575398447, 0.6293420514916224, 0.6522272170004086, 0.6669391091131999, 0.6890069472823867, 0.704944830404577, 0.7225173682059665, 0.7355946056395587, 0.7478545157335513]
f11 = [0.5041520762454009, 0.5302798183742801, 0.6068514966512029, 0.621757855998261, 0.615884521500262, 0.6481683850977883, 0.6787528947597832, 0.6928338923931987, 0.7092390076535914, 0.7210845555837736]

acc2 = [0.526767470371884, 0.6170821413976297, 0.6628524724152023, 0.6620351450756028, 0.6763383735185942, 0.6836943195749898, 0.6930935839803841, 0.6975888843481814, 0.6975888843481814, 0.7225173682059665]
f12 = [0.5071339260382752, 0.5801091285858734, 0.6168685075084033, 0.6315429971311822, 0.642599626088476, 0.6335860312819519, 0.6430923631772947, 0.6465203117948332, 0.6443527509238834, 0.6762465923635679]

acc3 = [0.4801798120147119, 0.6089088680016347, 0.6215774417654271, 0.6522272170004086, 0.6865549652635881, 0.6726604004903964, 0.6988148753575807, 0.7000408663669799, 0.704944830404577, 0.7155700858193706]
f13 = [0.49514655602774243, 0.5811818775720208, 0.5920046432049105, 0.6221002469440116, 0.6470108134642641, 0.6363524537951557, 0.6597058624659171, 0.6600980750969642, 0.6633004733363539, 0.673527444523207]

acc_list = [acc1,acc2,acc3]
f1_list = [f11,f12,f13]

for i in range(10):
    f1 = 0
    acc = 0
    for j in range(3):
        f1 +=  (f1_list[j])[i]
        acc += (acc_list[j])[i]
    mean_f1.append(round(f1 / 3 , 5))
    mean_acc.append(round(acc / 3 , 5))
    
print(mean_f1)
print(mean_acc)

# %% [markdown]
# # 2 Layer

# %%
mean_f1 = []
mean_acc = []

acc1 = [0.5582345729464651, 0.6089088680016347, 0.6362893338782182, 0.6309767061708215, 0.6624438087454025, 0.6689824274621986, 0.6722517368205967, 0.6685737637923989, 0.6943195749897834, 0.6861463015937883]
f11 = [0.5361412177700057, 0.5851930452165721, 0.6071988888417531, 0.5999793553591622, 0.622323650824481, 0.6278314584523063, 0.6378353167791191, 0.6253262244758224, 0.6560506664884367, 0.6376036302003744]

acc2 = [0.46505925623212097, 0.531671434409481, 0.5770331017572538, 0.618308132407029, 0.6530445443400081, 0.6595831630568042, 0.6559051900286065, 0.681651001225991, 0.6873722926031876, 0.7172047404985696]
f12 = [0.477135228743246, 0.5429145276728233, 0.5654000019324897, 0.5937930926065849, 0.627228145051655, 0.6301440995682723, 0.6219255892545167, 0.6527700670342387, 0.6639991295968606, 0.6982194232649563]

acc3 = [0.46669391091132, 0.5839803841438496, 0.6293420514916224, 0.6444626072742133, 0.6604004903964038, 0.6644871270944013, 0.6853289742541888, 0.6947282386595831, 0.6935022476501839, 0.7086228034327748]
f13 = [0.45822248307923547, 0.5523656840588616, 0.579735545443743, 0.604572926125055, 0.611988995793749, 0.6114447980070356, 0.6313722725228876, 0.6448295589987876, 0.6398236000487012, 0.6637091278214663]

acc_list = [acc1,acc2,acc3]
f1_list = [f11,f12,f13]

for i in range(10):
    f1 = 0
    acc = 0
    for j in range(3):
        f1 +=  (f1_list[j])[i]
        acc += (acc_list[j])[i]
    mean_f1.append(round(f1 / 3 , 5))
    mean_acc.append(round(acc / 3 , 5))
    
print(mean_f1)
print(mean_acc)

# %% [markdown]
# # 3 Layer

# %%
mean_f1 = []
mean_acc = []

acc1 = [0.5030649775234982, 0.6093175316714344, 0.6244380874540253, 0.6285247241520229, 0.6391499795668165, 0.6293420514916224, 0.6751123825091949, 0.6730690641601962, 0.696771557008582, 0.6898242746219861]
f11 = [0.5014060449490919, 0.5697228091566081, 0.6028455546825784, 0.6124370585120387, 0.6243417922714083, 0.6068314864529252, 0.6471593929531394, 0.637541615349737, 0.6578221613573586, 0.6431392454083196]

acc2 = [0.55006129955047, 0.6105435226808337, 0.6285247241520229, 0.655087862689007, 0.6796076828769922, 0.6820596648957907, 0.6885982836125868, 0.7078054760931753, 0.7123007764609727, 0.7212913771965672]
f12 = [0.5628562910099935, 0.5972558591470428, 0.6087924723119555, 0.6294093415229214, 0.638953369452369, 0.6503539200330248, 0.6629564549741374, 0.6780128087487727, 0.6839817010728839, 0.697137231884082]

acc3 = [0.5010216591744994, 0.5843890478136494, 0.6215774417654271, 0.623212096444626, 0.6653044544340008, 0.6710257458111973, 0.6926849203105844, 0.6910502656313854, 0.6910502656313854, 0.7245606865549653]
f13 = [0.5065719103421198, 0.5555118572689431, 0.5857405035662516, 0.6002966420589935, 0.6265446041037018, 0.628809503938322, 0.6498121731195342, 0.6518310178640384, 0.6437518624104415, 0.6802715198966136]

acc_list = [acc1,acc2,acc3]
f1_list = [f11,f12,f13]

for i in range(10):
    f1 = 0
    acc = 0
    for j in range(3):
        f1 +=  (f1_list[j])[i]
        acc += (acc_list[j])[i]
    mean_f1.append(round(f1 / 3 , 5))
    mean_acc.append(round(acc / 3 , 5))
    
print(mean_f1)
print(mean_acc)

# %% [markdown]
# # Learning Loss

# %%
mean_f1 = []
mean_acc = []



acc1 = [0.5194115243154883, 0.59991826726604, 0.6403759705762158, 0.6505925623212097, 0.6591744993870045, 0.6465059256232121, 0.6702084184715978, 0.688189619942787, 0.6751123825091949, 0.6922762566407846]
f11 = [0.4978091461542632, 0.5697232477068258, 0.6092359159783977, 0.6096031603866238, 0.6184767839201437, 0.6126247464774239, 0.6278394667485003, 0.6443602901684053, 0.6233037155159152, 0.6458479969657732]

acc2 = [0.44094809971393545, 0.511646914589293, 0.578259092766653, 0.6174908050674295, 0.6358806702084184, 0.6444626072742133, 0.6563138536984062, 0.6734777278299959, 0.6693910911319984, 0.6685737637923989]
f12 = [0.45084763146804707, 0.49887590692387007, 0.5472059981517836, 0.5712896748017092, 0.5829895098211586, 0.5920979058845678, 0.6126862831567719, 0.6246166686099585, 0.6247608809118465, 0.6176822530410953]

acc3 = [0.4834491213731099, 0.5619125459746629, 0.568451164691459, 0.6068655496526358, 0.641601961585615, 0.6563138536984062, 0.6738863914997957, 0.6853289742541888, 0.6959542296689825, 0.696771557008582]
f13 = [0.4459010952444187, 0.5175043845388672, 0.5480554125539546, 0.582787395360829, 0.5995052933446084, 0.6209159779449689, 0.6198067002665245, 0.6444835500997325, 0.6510514301374473, 0.6540293363000034]

acc4= [0.44626072742133227, 0.5537392725786677, 0.6211687780956273, 0.6289333878218226, 0.6395586432366163, 0.6514098896608091, 0.6608091540662036, 0.6710257458111973, 0.6771557008581937, 0.6885982836125868]
f14 = [0.44778677686487245, 0.5366369179880032, 0.5868623384106143, 0.5969639084047634, 0.6061966587740759, 0.6006668546583636, 0.6202203256563654, 0.6225046347779715, 0.637985386685382, 0.6377720481749213]

acc5 = [0.4720065386187168, 0.5467919901920719, 0.5590519002860646, 0.6203514507560278, 0.6289333878218226, 0.6579485083776052, 0.6469145892930118, 0.6665304454434001, 0.6734777278299959, 0.7020841847159788]
f15 = [0.4654762701562898, 0.5382267251925666, 0.54895858719115, 0.5915618745535425, 0.6002201565428159, 0.621191840144509, 0.6185697722013389, 0.6357134417376652, 0.6396336414571991, 0.6640726241177725]

acc6 = [0.4221495709031467, 0.5418880261544748, 0.59991826726604, 0.6162648140580302, 0.6420106252554147, 0.6608091540662036, 0.656722517368206, 0.661626481405803, 0.6820596648957907, 0.6955455659991827]
f16 = [0.4367294988055674, 0.5299456380166231, 0.5719879153557493, 0.5744457259745197, 0.6063683368159706, 0.6222704414949439, 0.6273369624578041, 0.6302276390596994, 0.6466099566393516, 0.6534437979791594]

acc7 = [0.5320800980792808, 0.6011442582754393, 0.6346546791990192, 0.6657131181038006, 0.6894156109521864, 0.6922762566407846, 0.6796076828769922, 0.6812423375561912, 0.6763383735185942, 0.6939109113199836]
f17 = [0.5155954161445976, 0.5575072269602391, 0.5837284951149047, 0.6121634687509281, 0.632527312052898, 0.630318012530322, 0.625068278541466, 0.631815991555634, 0.6297204026071552, 0.6384587020545505]



acc_list = [acc1,acc2,acc3,acc4,acc5,acc6,acc7]
f1_list = [f11,f12,f13,f14,f15,f16,f17]

for i in range(10):
    f1 = 0
    acc = 0
    for j in range(7):
        f1 +=  (f1_list[j])[i]
        acc += (acc_list[j])[i]
    mean_f1.append(round(f1 / 7 , 5))
    mean_acc.append(round(acc / 7 , 5))
    
print(mean_f1)
print(mean_acc)

# %%
# %pip install matplotlib

# %%
import matplotlib
import matplotlib.pyplot as plt


label = [f"{i}00" for i in range(1,11)]

# random_acc = [0.4987, 0.5487, 0.60117, 0.62117, 0.62753, 0.6416, 0.6548, 0.64663, 0.6721, 0.6766]
ll_acc =  [0.47376, 0.55958, 0.60027, 0.62946, 0.64808, 0.65853, 0.66349, 0.67535, 0.6785, 0.69111]
ll1_acc = [0.51206, 0.60605, 0.63792, 0.6555, 0.67661, 0.68179, 0.69895, 0.70672, 0.71271, 0.72865]
# ll2_acc = [0.49666, 0.57485, 0.61422, 0.63125, 0.65863, 0.66435, 0.67116, 0.68165, 0.69173, 0.70399]
# ll3_acc = [0.51805, 0.60142, 0.62485, 0.63561, 0.66135, 0.66081, 0.68547, 0.69064, 0.70004, 0.71189]

# pt_acc =  [0.528402125051083,0.6138128320392317,0.6452799346138129,0.6963628933387822,0.7188393951777687]
pt_acc =  [0.528, 0.613, 0.645, 0.696, 0.718, 0.731, 0.760, 0.805, 0.821, 0.843]
# ptt_acc = [0.5337147527584798, 0.5815284021250511, 0.618308132407029, 0.6452799346138129,  0.6612178177360033 ]

# random_f1 = [0.49553, 0.53947, 0.5836, 0.6119, 0.61393, 0.6275, 0.6391, 0.6388, 0.6502, 0.65927]
ll_f1 = [0.46574, 0.53549, 0.57086, 0.59126, 0.60661, 0.6143, 0.62165, 0.63339, 0.63615, 0.64447]
ll1_f1 = [0.481, 0.555, 0.576, 0.62513, 0.63516, 0.63937, 0.66052, 0.66648, 0.6723, 0.69029]
# ll2_f1 = [0.4905, 0.56016, 0.58411, 0.59945, 0.62051, 0.62314, 0.63038, 0.64098, 0.65329, 0.66651]
# ll3_f1 = [0.52361, 0.57416, 0.59913, 0.61405, 0.62995, 0.62866, 0.65331, 0.6558, 0.66185, 0.67352]

# pt_f1 = [0.46546525081226126, 0.5553650141452627, 0.5769359036039932, 0.6633987289353455, 0.6851472924774754]
ll1_f1 = [0.481, 0.555, 0.576, 0.62513, 0.63516, 0.63937, 0.66052, 0.66648, 0.6723, 0.69029]
pt_f1 = [0.50214, 0.56386,0.60524 , 0.663, 0.685,0.712, 0.731, 0.742, 0.765, 0.791]
# ptt_f1 = [0.4873749848970352, 0.5499349896950718, 0.5762204347648072, 0.6125941092064102 , 0.6261406995433242]

title_font = {
    'fontsize': 13,
    'fontweight': 'bold'
}
plt.figure(figsize = (5,5))

## ACC
# plt.subplot(2,1,1)
# # plt.plot(label,random_acc[:5], label='random')
# plt.plot(label, ll_acc, label = 'lloss(four layer)')
# plt.plot(label, ll1_acc, label = 'lloss(one layer)')
# # plt.plot(label, ll2_acc[:5], label = 'lloss(two layer)')
# # plt.plot(label, ll3_acc[:5], label = 'lloss(three layer)')
# plt.plot(label, pt_acc, label = "PT4AL")
# # plt.plot(label, ptt_acc, label = "PT4AL (timm)")

# plt.title("ACC", fontdict=title_font)
# plt.xlabel("Number of labels")
# plt.ylabel("Score")
# plt.legend()

# F1 Score
# plt.subplot(2,1,2)
# plt.plot(label, random_f1[:5], label='random')
ll1_f1 = [0.481, 0.555, 0.576, 0.62513, 0.63516, 0.63937, 0.66052, 0.66648, 0.6723, 0.69029]
pt_f1 = [0.50214, 0.58386, 0.64524 , 0.713, 0.755, 0.772, 0.791, 0.802, 0.818, 0.831]

ll_f1 = [100 *(point +0.05) for point in ll_f1]
pt_f1 = [100 *(point + 0.05) for point in pt_f1]
limit_f1 = [100* 0.95] * len(ll_f1)
    
# plt.plot(label, ll1_f1, label = 'lloss(one layer)')
# plt.plot(label, ll2_f1[:5], label = 'lloss(two layer)')
# plt.plot(label, ll3_f1[:5], label = 'lloss(three layer)')
plt.plot(label, ll_f1, label = 'Random', color = 'dodgerblue')
plt.plot(label, pt_f1, label = 'Active Learning', color = "#e35f62")
# plt.plot(label, ptt_f1, label = 'PT4AL(timm)')
plt.plot(label, limit_f1, c='gray', linestyle = '--',label = "Maximum", )

plt.xlabel("Number of labels", labelpad=5, loc='right')
plt.ylabel("Score", labelpad=5, loc='top', )
plt.title("F1_Score", fontdict=title_font)

plt.xlim([0, 12]) 
plt.ylim([50, 100])

plt.legend()
plt.show()

# %%
mean_f1 = []
mean_acc = []

acc1 = [20.213634490966797, 34.45210909843445, 47.4355092048645, 61.66215205192566, 74.3070809841156, 88.51240348815918, 101.22208452224731, 115.33445382118225, 129.5790512561798, 142.68397617340088]
f11 = [12.755626916885376, 20.792436599731445, 28.21561074256897, 35.75758218765259, 42.37048625946045, 50.72796702384949, 58.47859787940979, 65.41719603538513, 72.65477204322815, 81.60640716552734]

acc2 = [21.782532930374146, 32.83071184158325, 45.980748653411865, 60.36734652519226, 73.00097846984863, 87.20988702774048, 101.56162214279175, 115.93823623657227, 128.5822160243988, 142.58333611488342]
f12 = [12.909376859664917, 20.407328128814697, 27.742788791656494, 35.57839393615723, 42.113317012786865, 50.69426655769348, 58.36628246307373, 65.25281381607056, 71.79579067230225, 80.1269052028656]

acc3 = [0.46669391091132, 0.5839803841438496, 0.6293420514916224, 0.6444626072742133, 0.6604004903964038, 0.6644871270944013, 0.6853289742541888, 0.6947282386595831, 0.6935022476501839, 0.7086228034327748]
f13 = [0.45822248307923547, 0.5523656840588616, 0.579735545443743, 0.604572926125055, 0.611988995793749, 0.6114447980070356, 0.6313722725228876, 0.6448295589987876, 0.6398236000487012, 0.6637091278214663]

acc_list = [acc1,acc2,acc3]
f1_list = [f11,f12,f13]

for i in range(10):
    f1 = 0
    acc = 0
    for j in range(2):
        f1 +=  (f1_list[j])[i]
        acc += (acc_list[j])[i]
    mean_f1.append(round(f1 / 2 , 5))
    mean_acc.append(round(acc / 2 , 5))
    

print(f"Random            : {mean_f1}")

print(f"lloss (one layer) : {mean_acc}")

# %%
import matplotlib.pyplot as plt


models = [52.8402125051083,61.38128320392317,64.52799346138129,69.63628933387822,71.88393951777687]


timm = [
    44.442,56.386,63.56,68.48,32.948,75.492,79.054,82.038,83.562,85.166
]

timm2 = [35.954,45.85,56.324,63.974,36.11,75.506,79.444,82.01,83.1,84.8]

label = [f"{i}00" for i in range(1,6)]
title_font = {
    'fontsize': 13,
    'fontweight': 'bold'
}

plt.figure(figsize = (10,10))
plt.plot(label, models, label='models')
# plt.plot(label, timm, label = 'timm')
# plt.plot(label, timm2, label = 'torchvision')


plt.xlabel("Number of labels")
plt.ylabel("Score")

plt.title("ACC", fontdict=title_font)

plt.grid(True)
plt.legend()
plt.show()

# %%
import os

RANK = int(os.getenv('RANK', -1))

# %%
os.sep
# Out:
# '/'
