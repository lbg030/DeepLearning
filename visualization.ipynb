# %% [markdown]
# # Random Sampling

# %%
acc = [[0.6960, 0.7981, 0.8378, 0.7936, 0.8468]]
f1 = [[0.6674, 0.7879, 0.8338, 0.7816, 0.8425]]

# %% [markdown]
# # Learning Loss

# %%
mean_f1 = [[0.6751, 0.6951, 0.7274], [0.7748, 0.8067, 0.8149, 0.8149 ], [0.7924 ,0.8365 , 0.8414], [0.8108, 0.8463 , 0.8492],[0.8292, 0.8541 ]]
mean_acc = [[0.6541,0.6781 , 0.7076], [0.7541,0.7942, 0.8051, 0.8051 ],[0.7746, 0.8291, 0.8321 ], [0.7995, 0.8417, 0.8423], [0.8191, 0.8511 ]]

for j in range(5):
    f1_score = 0
    acc_score = 0
    for i in range(3):
        f1_score += f1[i][j]
        acc_score += acc[i][j]
    
    mean_f1[j] = f1_score / 3
    mean_acc[j] = acc_score / 3
    
print(mean_f1)
print(mean_acc)

# %%
import matplotlib.pyplot as plt

# 1/5
# accuracy : 0.5851
# f1 score : 0.5141
# precision : 0.4840
# recall : 0.5851

# 2/5
# accuracy : 0.6134
# f1 score : 0.5298
# precision : 0.4665
# recall : 0.6134



label = [200,400,600,800,1000]
acc = [0.6960, 0.7981, 0.8378, 0.7936, 0.8468]
f1 = [0.6674, 0.7879, 0.8338, 0.7816, 0.8425]
title_font = {
    'fontsize': 13,
    'fontweight': 'bold'
}


plt.plot(label,f1, label='f1_score')
plt.plot(label, acc, label = 'acc')

plt.xlabel("Number of labels")
plt.ylabel("Score")

plt.title('hz : 1732 bz : 448 yd : 169 chem : 330', fontdict=title_font)

plt.legend()
plt.show()
