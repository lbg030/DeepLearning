# %% [markdown]
# # Random Sampling

# %%
acc = [[0.6960,0.6792] ,[0.7981,0.7601], [0.7936,0.8378], [0.7936,0.8433] ,[0.8468,0.82]]
f1 = [[0.6674,0.6660] , [0.7879,0.7486], [0.8338,0.7849] , [0.7816,0.8433], [0.8425, 0.821]]

# %% [markdown]
# # Learning Loss

# %%
mean_f1 = []
mean_acc = []

f1 = [[0.6751, 0.6951, 0.7274], [0.7748, 0.8067, 0.8149 ], [0.7924 ,0.8365 , 0.8414], [0.8108, 0.8463 , 0.8492],[0.8292, 0.8541, 0.8541 ]]
acc = [[0.6541,0.6781 , 0.7076], [0.7541,0.7942, 0.8051 ],[0.7746, 0.8291, 0.8321 ], [0.7995, 0.8417, 0.8423], [0.8191, 0.8511 ,0.8511]]

for i in range(5):
    mean_f1.append(round(sum(f1[i]) / 3,5))
    mean_acc.append(round(sum(acc[i]) / 3,6))
    
print(mean_f1)
print(mean_acc)
# Out:
# [0.6992, 0.7988, 0.82343, 0.83543, 0.8458]
# [0.679933, 0.784467, 0.811933, 0.827833, 0.840433]

# %%
import matplotlib.pyplot as plt


label = [f"{i}K" for i in range(1,6)]

cls_acc = [0.6667, 0.76825, 0.80935, 0.81245, 0.83175]
ll_acc = [0.6667, 0.784467, 0.811933, 0.827833, 0.840433]

# cls_f1 = [0.6876, 0.7791, 0.8157, 0.81845, 0.8334]
# ll_f1 = [0.6876, 0.7988, 0.82343, 0.83543, 0.8458]

title_font = {
    'fontsize': 13,
    'fontweight': 'bold'
}


plt.plot(label,cls_acc, label='random')
plt.plot(label, ll_acc, label = 'lloss')

plt.xlabel("Number of labels")
plt.ylabel("Score")

plt.title("F1-score", fontdict=title_font)

plt.legend()
plt.show()
